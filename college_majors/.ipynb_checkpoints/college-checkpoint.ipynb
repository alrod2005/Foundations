# %% [markdown]
# ## Introduction
#
# We'll explore how using the pandas plotting functionality along with the Jupyter notebook interface allows us to explore data quickly using visualizations.
#
# We'll be working with a dataset on the job outcomes of students who graduated from college between 2010 and 2012. The original data on job outcomes was released by [American Community Survey](https://www.census.gov/programs-surveys/acs/), which conducts surveys and aggregates the data. FiveThirtyEight cleaned the dataset and released it on their [Github repo](https://github.com/fivethirtyeight/data/tree/master/college-majors).

# %% [markdown]
# ## Assignment
#
# - Import pandas and matplotlib (remember "% matplotlib inline")
# - Read in the data and explore the head and tail
# - Drop any rows with missing values

# %%
% matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
grads = pd.read_csv("recent-grads.csv")

grads = grads.dropna()
grads.head(2)
grads.tail(2)
# Out:
#      Rank  Major_code                  Major            Major_category  Total  \
# 171   172        5203  COUNSELING PSYCHOLOGY  Psychology & Social Work   4626
# 172   173        3501        LIBRARY SCIENCE                 Education   1098
#
#      Sample_size  Men  Women  ShareWomen  Employed      ...        Part_time  \
# 171           21  931   3695    0.798746      3777      ...              965
# 172            2  134    964    0.877960       742      ...              237
#
#      Full_time_year_round  Unemployed  Unemployment_rate  Median  P25th  \
# 171                  2738         214           0.053621   23400  19200
# 172                   410          87           0.104946   22000  20000
#
#      P75th  College_jobs  Non_college_jobs  Low_wage_jobs
# 171  26000          2403              1245            308
# 172  22000           288               338            192
#
# [2 rows x 21 columns]

# %% [markdown]
# ## Assignment
#
# Feel free to use native panda graphing methods.
#
# - Make a scatter plot of sample size vs. median
# - Make a scatter plot of sample size vs. unemployment rate
# - Make a scatter plot of full time vs. median
# - Make a scatter plot of men vs. median
# - Make a scatter plot of women vs. median

# %%
grads.plot(x = "Sample_size", y = 'Median', kind = 'scatter')
grads.plot(x = "Sample_size", y = 'Unemployment_rate', kind = 'scatter')
grads.plot(x = "Full_time", y = 'Median', kind = 'scatter' )
grads.plot(x = "Men", y = "Women", kind = 'scatter')
grads.plot(x = "Women", y = "Median", kind = 'scatter')

# %% [markdown]
# ## Assignment
#
# - Create a for loop that plots the histogram of sample size, median, employed, full time, unemployment rate, men and women (remember to use the exact column titles)

# %%
columns = ["Sample_size", "Median", "Employed", "Full_time", "Unemployment_rate", "Men", "Women"]

fig = plt.figure(figsize = (10,10))

for r in range(1,5):
    ax = fig.add_subplot(4,1,r)
    ax = grads[columns[r]].plot(kind = 'hist', rot = 20)

# %% [markdown]
# ## Assignment
#
# - Make a scatter matrix of sample size and median
# - Make a scatter matrix of sample size, median and unemployment rate

# %%
from pandas.tools.plotting import scatter_matrix

scatter_matrix(grads[['Sample_size', 'Median']], figsize = (10,10))

scatter_matrix(grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize = (10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11895d128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118b4deb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118b84da0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x118bd32e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117d3e7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1175b6400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11791f080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1177878d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117916438>]], dtype=object)

# %% [markdown]
# ## Assignment
#
# - Make a bar plot of majors vs "ShareWomen" (you should run different slices since there are many different majors)

# %%
#Top 10 Median salary 
grads[:10].plot.bar(x = 'Major', y = 'ShareWomen')

#Bottom 10 Median Salary
grads[162:].plot.bar(x = 'Major', y = 'ShareWomen')
